# %% [markdown]
# # Pandas Time Series Exercise Set #1
#
# For this set of exercises we'll use a dataset containing monthly milk production values in pounds per cow from January 1962 to December 1975.
#
# <div class="alert alert-danger" style="margin: 10px"><strong>IMPORTANT NOTE!</strong> Make sure you don't run the cells directly above the example output shown, <br>otherwise you will end up writing over the example output!</div>

# %%
# RUN THIS CELL
import pandas as pd
# %matplotlib inline

df = pd.read_csv('monthly_milk_production.csv', encoding='utf8')
title = "Monthly milk production: pounds per cow. Jan '62 - Dec '75"

print(len(df))
print(df.head())
# Out:
# 168
#       Date  Production
# 0  1962-01         589
# 1  1962-02         561
# 2  1962-03         640
# 3  1962-04         656
# 4  1962-05         727

# %% [markdown]
# So <tt>df</tt> has 168 records and 2 columns.

# %% [markdown]
# ### 1. What is the current data type of the Date column?
# HINT: We show how to list column dtypes in the first set of DataFrame lectures.

# %%
type(df['Date'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 2 columns):
# Date          168 non-null object
# Production    168 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.7+ KB

# %%
df.describe(include = 'all')
# Out:
#            Date  Production
# count       168  168.000000
# unique      168         NaN
# top     1975-11         NaN
# freq          1         NaN
# mean        NaN  754.708333
# std         NaN  102.204524
# min         NaN  553.000000
# 25%         NaN  677.750000
# 50%         NaN  761.000000
# 75%         NaN  824.500000
# max         NaN  969.000000

# %%
# CODE HERE
df.dtypes
# Out:
# Date          object
# Production     int64
# dtype: object

# %%
# DON'T WRITE HERE
# Out:
# Date          object
# Production     int64
# dtype: object

# %% [markdown]
# ### 2. Change the Date column to a datetime format

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date          datetime64[ns]
# Production             int64
# dtype: object

# %%
# DON'T WRITE HERE
# Out:
# Date          datetime64[ns]
# Production             int64
# dtype: object

# %% [markdown]
# ### 3. Set the Date column to be the new index

# %%
df.set_index('Date',inplace = True)
df.head()
# Out:
#             Production
# Date
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727

# %%
# DON'T WRITE HERE
# Out:
#             Production
# Date
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727

# %% [markdown]
# ### 4. Plot the DataFrame with a simple line plot. What do you notice about the plot?

# %%
df.plot();

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 5. Add a column called 'Month' that takes the month value from the index
# HINT: You have to call <tt>df.index</tt> as <tt>df['Date']</tt> won't work.
#
# <strong>BONUS: See if you can obtain the <em>name</em> of the month instead of a number!</strong>

# %%
from datetime import datetime as dt

# %%
df['Month'] = df.index.strftime('%B')
df['month'] = df.index.month

# %%
df.head()
# Out:
#             Production     Month  month
# Date
# 1962-01-01         589   January      1
# 1962-02-01         561  February      2
# 1962-03-01         640     March      3
# 1962-04-01         656     April      4
# 1962-05-01         727       May      5

# %%
# DON'T WRITE HERE

# %%
# BONUS SOLUTION:
# Out:
#             Production     Month
# Date
# 1962-01-01         589   January
# 1962-02-01         561  February
# 1962-03-01         640     March
# 1962-04-01         656     April
# 1962-05-01         727       May

# %% [markdown]
# ### 6. Create a BoxPlot that groups by the Month field

# %%
ax = df.boxplot('Production',by = 'month',figsize = (10,5))

# %%
df['Production'].rolling(window = 7).mean().plot(figsize = (12,3)).autoscale(axis = 'x', tight = True);
df['Production'].plot()

# %%
# DON'T WRITE HERE

# %% [markdown]
# # Great Job!

# %%
df['Production'].expanding(min_periods = 7).mean().plot(figsize = (12,3)).autoscale(axis = 'x', tight = True);
df['Production'].plot()
